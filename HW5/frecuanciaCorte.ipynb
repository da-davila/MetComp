# %%
# %pylab inline
import scikits.audiolab as audio
from scipy.fftpack import fft, fftfreq
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
input_signal, sampling_rate, enc = audio.wavread("grabacion.wav")

print (input_signal[0:5]), sampling_rate, enc
# Out:
# [ -3.05175781e-05   1.09863281e-03  -3.11279297e-03   6.16455078e-03
#   -5.64575195e-03] 48000 pcm16

# %%
time_array = arange(0, len(input_signal)/float(sampling_rate), 1/float(sampling_rate))

# %%
plot(time_array[0:114000], input_signal[0:114000])
xlabel("time(s)", fontsize=20)
ylabel("Amplitude", fontsize=20)

# %%
n = len(time_array) # number of point in the whole interval
f = 200.0 #  frequency in Hz
dt = 1 / (f * n/7. ) #32 samples per frequency

# %%
TransFou = fft(input_signal)/len(input_signal)
freq = fftfreq(n, dt)
print max(np.abs(freq))
plot(time_array,freq)
# Out:
# 1872457.14286

# %%
freq_corte = mean(np.abs(freq))
TransFou[np.abs(freq) > freq_corte] = 0

# %%
nuevDat = ifft(TransFou).real

# %%
plot(time_array, nuevDat)
xlabel("time(s)", fontsize=20)
ylabel("Amplitude", fontsize=20)

# %%
output_file = audio.Sndfile("vozLimpia.wav", 'w', audio.Format('wav'), 1, sampling_rate)

# %%
output_file.write_frames(nuevDat)
output_file.close()
