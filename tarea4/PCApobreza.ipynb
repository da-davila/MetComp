# %%
# %pylab inline
import csv
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv('pobreza.csv' , sep = " ")

# %%
data = data.loc[:, ['Analfabetismo', 'Inasistencia.Escolar',  'Alta.Dependencia.Económica', 'Sin.Fuente.Agua.Mejorada']]

# %%
for i in range(4):
    data.ix[:,i] = data.ix[:,i] - mean(data)[i]

# %%
vals = svd(data)[2]

# %%
Props = vals*vals

# %%
plot(vals)
